# %%
import pandas as pd
import matplotlib.pyplot as plt
df_fitness_original = pd.read_csv("../data/smart_fitness_&_nutrition_analytics.csv")

# %% [markdown]
# Exploracion inicial del dataset

# %% [markdown]
# Veamos 10 filas para tener un ejemplo visual de lo que tenemos

# %%
df_fitness_original.sample(10)
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 12845  24.11    Male        51.37        1.67   178.42   132.74        71.92
# 19557  37.09    Male       123.90        1.76   167.80   158.01        50.09
# 17864  29.62  Female       108.40        1.66   193.94   140.35        64.13
# 17285  42.87  Female        95.37        1.77   197.92   150.77        49.99
# 14952  49.94  Female        51.14        1.71   199.30   155.04        63.86
# 14648  29.57    Male        67.85        1.75   179.81   167.90        67.10
# 6634   45.00    Male        50.12        1.65   170.24   135.66        50.02
# 13888  55.05  Female        75.27        1.71   173.30   130.31        56.92
# 9962   59.13  Female        42.51        1.65   171.56   132.30        59.06
# 12160  25.83  Female        54.07        1.65   171.91   119.71        57.81
#
#        Session_Duration (hours)  Calories_Burned Workout_Type  ...  \
# 12845                      0.97           640.78         Yoga  ...
# 19557                      1.52          1839.20         HIIT  ...
# 17864                      1.08          1037.66       Cardio  ...
# 17285                      1.08          1070.17     Strength  ...
# 14952                      1.48          1787.54         HIIT  ...
# 14648                      1.25          1512.50         HIIT  ...
# 6634                       1.45          1435.50     Strength  ...
# 13888                      1.03          1360.73         HIIT  ...
# 9962                       1.23          1492.36         HIIT  ...
# 12160                      1.06           763.20         Yoga  ...
#
#        cal_from_macros  pct_carbs  protein_per_kg   pct_HRR  pct_maxHR  \
# 12845          2419.68   0.499074        2.373759  0.571080   0.743975
# 19557          1768.10   0.500854        0.714770  0.916829   0.941657
# 17864          2385.66   0.501262        1.096402  0.587166   0.723677
# 17285          1651.02   0.499861        0.867464  0.681268   0.761772
# 14952          2190.83   0.500596        2.142550  0.673213   0.777923
# 14648          1625.44   0.499163        1.198231  0.894331   0.933763
# 6634           1873.13   0.501001        1.865922  0.712361   0.796875
# 13888          2456.50   0.500110        1.632789  0.630607   0.751933
# 9962           1706.05   0.501181        1.993649  0.651022   0.771159
# 12160          1714.13   0.499169        1.592010  0.542507   0.696353
#
#        cal_balance  lean_mass_kg  expected_burn  \
# 12845       832.22     39.269589       669.3776
# 19557      1532.80     80.535000       848.9808
# 17864      2059.34     70.460000       795.8952
# 17285      1375.83     62.664348       797.4504
# 14952      -398.54     39.647434      1012.2904
# 14648       206.50     51.155719       903.4500
# 6634        -67.50     39.787459       979.6490
# 13888       924.27     56.214725       756.8440
# 9962       -271.36     34.165483       831.5046
# 12160       819.80     41.387116       762.5852
#
#        Burns Calories (per 30 min)_bc  Burns_Calories_Bin
# 12845                    7.697389e+19              Medium
# 19557                    1.368981e+19                 Low
# 17864                    1.316498e+20           Very High
# 17285                    1.337662e+20           Very High
# 14952                    7.158922e+19              Medium
# 14648                    1.123279e+20           Very High
# 6634                     6.474780e+19              Medium
# 13888                    1.285590e+20           Very High
# 9962                     6.506155e+19              Medium
# 12160                    1.081571e+20                High
#
# [10 rows x 54 columns]

# %% [markdown]
# Como son muchas columnas, vamos a verlas de otra manera para saber todas las que tenemos pudiendo scrollear

# %%
for i in df_fitness_original:
	print(i)
# Out:
# Age
# Gender
# Weight (kg)
# Height (m)
# Max_BPM
# Avg_BPM
# Resting_BPM
# Session_Duration (hours)
# Calories_Burned
# Workout_Type
# Fat_Percentage
# Water_Intake (liters)
# Workout_Frequency (days/week)
# Experience_Level
# BMI
# Daily meals frequency
# Physical exercise
# Carbs
# Proteins
# Fats
# Calories
# meal_name
# meal_type
# diet_type
# sugar_g
# sodium_mg
# cholesterol_mg
# serving_size_g
# cooking_method
# prep_time_min
# cook_time_min
# rating
# Name of Exercise
# Sets
# Reps
# Benefit
# Burns Calories (per 30 min)
# Target Muscle Group
# Equipment Needed
# Difficulty Level
# Body Part
# Type of Muscle
# Workout
# BMI_calc
# cal_from_macros
# pct_carbs
# protein_per_kg
# pct_HRR
# pct_maxHR
# cal_balance
# lean_mass_kg
# expected_burn
# Burns Calories (per 30 min)_bc
# Burns_Calories_Bin

# %% [markdown]
# Vamos a ver con cuantas filas y columnas estamos trabajando

# %%
print(df_fitness_original.shape)
# Out:
# (20000, 54)

# %% [markdown]
# Vamos a ver un poco como es la contabilidad de valores

# %%
df_fitness_original.describe()
# Out:
#                 Age   Weight (kg)    Height (m)       Max_BPM       Avg_BPM  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      38.851454     73.898832      1.723094    179.889702    143.704306
# std       12.114580     21.173010      0.127033     11.510805     14.267688
# min       18.000000     39.180000      1.490000    159.310000    119.070000
# 25%       28.170000     58.160000      1.620000    170.057500    131.220000
# 50%       39.865000     70.000000      1.710000    180.140000    142.990000
# 75%       49.630000     86.100000      1.800000    189.425000    156.060000
# max       59.670000    130.770000      2.010000    199.640000    169.840000
#
#         Resting_BPM  Session_Duration (hours)  Calories_Burned  \
# count  20000.000000              20000.000000     20000.000000
# mean      62.195813                  1.259446      1280.109601
# std        7.289351                  0.341336       502.228982
# min       49.490000                  0.490000       323.110000
# 25%       55.960000                  1.050000       910.800000
# 50%       62.200000                  1.270000      1231.450000
# 75%       68.090000                  1.460000      1553.112500
# max       74.500000                  2.020000      2890.820000
#
#        Fat_Percentage  Water_Intake (liters)  ...      BMI_calc  \
# count    20000.000000           20000.000000  ...  20000.000000
# mean        26.101313               2.627486  ...     24.921651
# std          4.996160               0.604724  ...      6.701144
# min         11.333134               1.460000  ...     12.037907
# 25%         22.387807               2.170000  ...     20.094975
# 50%         25.822504               2.610000  ...     24.119097
# 75%         29.676026               3.120000  ...     28.562620
# max         35.000000               3.730000  ...     50.229544
#
#        cal_from_macros     pct_carbs  protein_per_kg       pct_HRR  \
# count     20000.000000  20000.000000    20000.000000  20000.000000
# mean       1998.297076      0.499983        1.460142      0.699005
# std         440.848408      0.001455        0.518946      0.144880
# min        1105.570000      0.492434        0.516706      0.371344
# 25%        1661.022500      0.499054        1.076294      0.583656
# 50%        1943.130000      0.499981        1.382260      0.686284
# 75%        2271.950000      0.500910        1.750495      0.798196
# max        3699.540000      0.507889        3.916881      1.073939
#
#           pct_maxHR   cal_balance  lean_mass_kg  expected_burn  \
# count  20000.000000  20000.000000  20000.000000   20000.000000
# mean       0.802305    744.308699     53.786384     866.352318
# std        0.096613    720.946619     12.498740     250.317069
# min        0.599789  -1266.220000     30.946261     219.852800
# 25%        0.727676    261.432500     44.587037     714.098250
# 50%        0.794834    691.190000     51.204908     868.721400
# 75%        0.869211   1176.290000     61.939016    1012.532700
# max        1.047032   3075.580000     90.117371    1477.108800
#
#        Burns Calories (per 30 min)_bc
# count                    2.000000e+04
# mean                     8.631802e+19
# std                      3.197579e+19
# min                      2.491905e+16
# 25%                      6.441978e+19
# 50%                      8.371578e+19
# 75%                      1.100442e+20
# max                      1.756614e+20
#
# [8 rows x 39 columns]

# %% [markdown]
# Vamos a ver un poco los tipos que tenemos

# %%
df_fitness_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             20000 non-null  float64
#  1   Gender                          20000 non-null  object
#  2   Weight (kg)                     20000 non-null  float64
#  3   Height (m)                      20000 non-null  float64
#  4   Max_BPM                         20000 non-null  float64
#  5   Avg_BPM                         20000 non-null  float64
#  6   Resting_BPM                     20000 non-null  float64
#  7   Session_Duration (hours)        20000 non-null  float64
#  8   Calories_Burned                 20000 non-null  float64
#  9   Workout_Type                    20000 non-null  object
#  10  Fat_Percentage                  20000 non-null  float64
#  11  Water_Intake (liters)           20000 non-null  float64
#  12  Workout_Frequency (days/week)   20000 non-null  float64
#  13  Experience_Level                20000 non-null  float64
#  14  BMI                             20000 non-null  float64
#  15  Daily meals frequency           20000 non-null  float64
#  16  Physical exercise               20000 non-null  float64
#  17  Carbs                           20000 non-null  float64
#  18  Proteins                        20000 non-null  float64
#  19  Fats                            20000 non-null  float64
#  20  Calories                        20000 non-null  float64
#  21  meal_name                       20000 non-null  object
#  22  meal_type                       20000 non-null  object
#  23  diet_type                       20000 non-null  object
#  24  sugar_g                         20000 non-null  float64
#  25  sodium_mg                       20000 non-null  float64
#  26  cholesterol_mg                  20000 non-null  float64
#  27  serving_size_g                  20000 non-null  float64
#  28  cooking_method                  20000 non-null  object
#  29  prep_time_min                   20000 non-null  float64
#  30  cook_time_min                   20000 non-null  float64
#  31  rating                          20000 non-null  float64
#  32  Name of Exercise                20000 non-null  object
#  33  Sets                            20000 non-null  float64
#  34  Reps                            20000 non-null  float64
#  35  Benefit                         20000 non-null  object
#  36  Burns Calories (per 30 min)     20000 non-null  float64
#  37  Target Muscle Group             20000 non-null  object
#  38  Equipment Needed                20000 non-null  object
#  39  Difficulty Level                20000 non-null  object
#  40  Body Part                       20000 non-null  object
#  41  Type of Muscle                  20000 non-null  object
#  42  Workout                         20000 non-null  object
#  43  BMI_calc                        20000 non-null  float64
#  44  cal_from_macros                 20000 non-null  float64
#  45  pct_carbs                       20000 non-null  float64
#  46  protein_per_kg                  20000 non-null  float64
#  47  pct_HRR                         20000 non-null  float64
#  48  pct_maxHR                       20000 non-null  float64
#  49  cal_balance                     20000 non-null  float64
#  50  lean_mass_kg                    20000 non-null  float64
#  51  expected_burn                   20000 non-null  float64
#  52  Burns Calories (per 30 min)_bc  20000 non-null  float64
#  53  Burns_Calories_Bin              20000 non-null  object
# dtypes: float64(39), object(15)
# memory usage: 8.2+ MB

# %% [markdown]
# Vamos a revisar si hay valores nulos

# %%
df_fitness_original[df_fitness_original.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Daily meals frequency, Physical exercise, Carbs, Proteins, Fats, Calories, meal_name, meal_type, diet_type, sugar_g, sodium_mg, cholesterol_mg, serving_size_g, cooking_method, prep_time_min, cook_time_min, rating, Name of Exercise, Sets, Reps, Benefit, Burns Calories (per 30 min), Target Muscle Group, Equipment Needed, Difficulty Level, Body Part, Type of Muscle, Workout, BMI_calc, cal_from_macros, pct_carbs, protein_per_kg, pct_HRR, pct_maxHR, cal_balance, lean_mass_kg, expected_burn, Burns Calories (per 30 min)_bc, Burns_Calories_Bin]
# Index: []
#
# [0 rows x 54 columns]

# %% [markdown]
# Vamos a visualizar como estan los valores de: Exercise, Sets, Reps, Benefit, Target Muscle Group, Equipment Needed, Difficulty Level, Body Part, Type of Muscle y Workout

# %%
df_fitness_original[["Name of Exercise", "Sets", "Reps", "Benefit", "Target Muscle Group", "Equipment Needed", "Difficulty Level", "Body Part", "Type of Muscle", "Workout"]]
# Out:
#         Name of Exercise  Sets   Reps  \
# 0       Decline Push-ups  4.99  20.91
# 1            Bear Crawls  4.01  16.15
# 2                   Dips  5.00  21.90
# 3      Mountain Climbers  4.01  16.92
# 4            Bicep Curls  4.99  15.01
# ...                  ...   ...    ...
# 19995         Frog Jumps  4.99  17.14
# 19996           Pull-ups  5.01  23.08
# 19997               Dips  4.00  18.91
# 19998        Plyo Squats  3.99  24.97
# 19999        Tricep Dips  4.00  16.15
#
#                                                Benefit  \
# 0                 Improves shoulder health and posture
# 1                                Strengthens lower abs
# 2                                Builds chest strength
# 3      Improves coordination and cardiovascular health
# 4          Targets obliques and improves core rotation
# ...                                                ...
# 19995                  Improves cardiovascular fitness
# 19996                        Strengthens back and legs
# 19997                            Builds shoulder width
# 19998                              Builds calf muscles
# 19999             Improves shoulder health and posture
#
#                   Target Muscle Group        Equipment Needed  \
# 0                  Shoulders, Triceps           Cable Machine
# 1               Back, Core, Shoulders             Step or Box
# 2                  Quadriceps, Glutes             Step or Box
# 3                    Biceps, Forearms  Parallel Bars or Chair
# 4                      Chest, Triceps                    Wall
# ...                               ...                     ...
# 19995  Quadriceps, Hamstrings, Glutes         Box or Platform
# 19996           Core, Shoulders, Hips    Dumbbells or Barbell
# 19997       Upper Back, Rear Deltoids                 Barbell
# 19998       Rear Deltoids, Upper Back             Pull-up Bar
# 19999                  Chest, Triceps             Pull-up Bar
#
#       Difficulty Level  Body Part   Type of Muscle                 Workout
# 0             Advanced       Legs             Lats          Dumbbell flyes
# 1         Intermediate      Chest             Lats          Lateral raises
# 2         Intermediate       Arms    Grip Strength    Standing calf raises
# 3             Advanced  Shoulders            Upper  Incline dumbbell flyes
# 4             Advanced        Abs    Wrist Flexors          Military press
# ...                ...        ...              ...                     ...
# 19995         Advanced       Arms         Anterior       Triceps pushdowns
# 19996     Intermediate       Arms             Lats      Seated calf raises
# 19997         Beginner   Forearms  Wrist Extensors          Russian twists
# 19998     Intermediate  Shoulders         Anterior               Leg curls
# 19999         Advanced  Shoulders          Lateral          Dumbbell flyes
#
# [20000 rows x 10 columns]

# %% [markdown]
# Terminando de ver un poco el dataset, veo diferentes cosas que quiero cambiar.
# -  1º Los nombres de las columnas, para tener un manejo mas facil cambiare los nombres a minusculas, cambiando los espacios por barras bajas y eleminando los parentesis.
# -  2º Tambien voy a quitar las mayusculas de los valores por el mismo motivo, tener un manejo mas facil.
# -  3º Cambiare los valores de "age" a numeros enteros, a la hora de hacer graficas con ello sera mejor asi para no tener 1000 barras y ademas no me parece interesante los valores decimales, o tienes x edad o no la tienes.
# -  4º Un poco de la misma manera, cambiare "fat_percentage" a valores enteros, ya que si no, vamos a tener demaciados valores diferentes con tantos decimales y no creo que sea muy interesante.
# -  5º Voy a eliminar las columnas de: Exercise, Sets, Reps, Benefit, Target Muscle Group, Equipment Needed, Difficulty Level, Body Part, Type of Muscle y Workout, ya que cuando se hace una sesion de entrenamiento, lo normal es hacer varios ejercicios, cada ejercicio con sus propios sets, repeticiones, beneficios, etc, tal cual esta puesto en el dataframe es como si cada persona solamente hiciera un ejercicio en una sesion de entrenamiento y ademas es el unico ejercicio que hace en todas las sesiones y siempre con los mismos, eso no me parece que sea algo que sirva para ver realmente que ejercicios hace, como los va haciendo, ver una evolucion ni nada, ademas en algunos casos he notado la incoherencia de que trabaja unos ejercicios para unas partes del cuerpo pero luego en la columna de Body part te pone otra parte del cuerpo distinta.
